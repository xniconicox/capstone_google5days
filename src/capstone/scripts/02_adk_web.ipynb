# %% [markdown]
# # 📘 **Notebook: STAC Agent – Run ADK web UI**
#
# ---
#
# ##  ** Setup**

# %%
import sys
from pathlib import Path

# Project root should be the capstone directory
PROJECT_ROOT = Path(".").resolve().parents[2]
print("PROJECT_ROOT:", PROJECT_ROOT)

# Optional: ensure src/ is importable, in case you want to import agent code later
sys.path.insert(0, str(PROJECT_ROOT / "src"))
# Out:
# PROJECT_ROOT: /home/kimura/work/google5days/capstone

# %% [markdown]
# ## Start ADK Web UI
#
# The following cell starts the ADK Web UI (`adk web`).
#
# - It will block the notebook cell while the server is running.
# - After running the cell, open the printed URL in your browser.
# - To stop the server, interrupt the kernel or stop the cell execution.

# %%
# Start the ADK Web UI with debug logging.
# Run this cell once, then open the URL that appears in the output.

# !adk web --log_level DEBUG
# Out:
# 2025-11-24 15:49:23,337 - DEBUG - service_registry.py:207 - services.py not found in /home/kimura/work/google5days/capstone/src/capstone/scripts, skipping.
# /home/kimura/work/google5days/.venv/lib/python3.11/site-packages/google/adk/cli/fast_api.py:138: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /home/kimura/work/google5days/.venv/lib/python3.11/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# 2025-11-24 15:49:23,395 - DEBUG - selector_events.py:54 - Using selector: EpollSelector
# INFO:     Started server process [129174]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# 2025-11-24 15:49:25,468 - INFO - adk_web_server.py:605 - New session created: e6c825de-e46a-4c9b-aca7-fb0b262769e7
# INFO:     127.0.0.1:36062 - "POST /apps/eval/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36062 - "GET /apps/eval/users/user/sessions/e6c825de-e46a-4c9b-aca7-fb0b262769e7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36062 - "GET /debug/trace/session/e6c825de-e46a-4c9b-aca7-fb0b262769e7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36062 - "GET /apps/eval/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36062 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-24 15:49:28,682 - INFO - envs.py:47 - Loaded .env file for eval at /home/kimura/work/google5days/.env
# 2025-11-24 15:49:28,682 - DEBUG - agent_loader.py:325 - Loading agent eval - not in cache.
# 2025-11-24 15:49:28,682 - DEBUG - agent_loader.py:224 - Loading .env for agent eval from /home/kimura/work/google5days/capstone/src/capstone/scripts
# 2025-11-24 15:49:28,683 - INFO - envs.py:47 - Loaded .env file for eval at /home/kimura/work/google5days/.env
# 2025-11-24 15:49:28,683 - DEBUG - agent_loader.py:89 - Module eval has no root_agent. Trying next pattern.
# 2025-11-24 15:49:28,687 - INFO - agent_loader.py:127 - Found root_agent in eval.agent
# 2025-11-24 15:49:28,751 - INFO - google_llm.py:163 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-24 15:49:28,752 - DEBUG - google_llm.py:169 -
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are a satellite metadata search agent. You translate natural language queries
# into STAC search parameters and call the `search_satellite_scenes` tool.
#
# Your primary goal is to help the user find suitable Earth observation scenes
# by converting natural language queries into precise STAC search parameters
# and by clearly explaining the search results.
#
# You have access to two tools:
# - "resolve_aoi": maps a location hint or AOI id to a canonical AOI (bbox, center, note, default cloud cover).
# - "search_satellite_scenes": queries a STAC API for scenes.
#
# The search tool expects the following arguments:
# - bbox: [min_lon, min_lat, max_lon, max_lat]
# - datetime_range: ISO 8601 interval string "start/end" (UTC)
# - cloud_cover_max: maximum allowed cloud cover in percent (0–100)
# - limit (optional): maximum number of scenes to return
# - collections (optional): list of STAC collection IDs, e.g. ["sentinel-2-l2a"]
#
# Tool usage:
# - When you have enough information to perform a search, call the "search_satellite_scenes" tool
#   with carefully constructed arguments.
# - Do not invent fields or change the tool schema; always respect the defined input schema.
# - Validate arguments logically before calling the tool (for example, start date must be before
#   end date, bbox must have min_lon < max_lon and min_lat < max_lat).
# - If user constraints are impossible or inconsistent, ask for clarification instead of
#   calling the tool with invalid parameters.
#
# General behavior:
# - Always aim to return scenes that match the user's intent as closely as possible.
# - Prefer asking clarification questions over guessing when the user query is ambiguous
#   (for example, vague locations like "northern Europe" or vague times like "last winter").
# - Be explicit about any assumptions you make (for example, the exact date range you chose
#   for "summer 2023" or the approximate bounding box used for a named region).
# - If the tool returns no results, try to reason about why (too strict cloud_cover,
#   too short time range, too small area, wrong collection) and propose concrete ways
#   to relax or adjust the constraints.
#
# Location handling (clarify-first):
# - If the user provides an explicit bounding box, use it directly.
# - Otherwise, ALWAYS call the "resolve_aoi" tool first when the user mentions
#   a place name, AOI id, region, or city. Use the canonical bbox and any default
#   cloud cover returned by resolve_aoi.
# - If you do not recognize the place name (resolve_aoi matched = false), first
#   ask the user for a location or coordinates instead of guessing a bbox.
# - If you have a reasonable guess of the approximate area, propose a center
#   coordinate and ask for confirmation before calling the search tool. Example:
#   "I can search around lon X, lat Y; is that okay? If not, please provide a bbox."
# - Use known AOI IDs exactly as listed below. Do not invent new AOI IDs.
# - Never fabricate impossible coordinates. Longitudes must be in [-180, 180],
#   latitudes in [-90, 90].
#
#
# Known AOIs (use these bounding boxes when the phrase matches exactly):
# - japan: [122.0, 24.0, 153.0, 46.0] (Japan main islands)
# - usa_mainland: [-125.0, 24.0, -66.5, 49.5] (Contiguous United States)
# - united_kingdom: [-8.0, 49.5, 2.5, 59.0] (United Kingdom)
# - france: [-5.5, 41.0, 9.8, 51.5] (France)
# - germany: [5.5, 47.0, 15.5, 55.5] (Germany)
# - tokyo_area: [138.8, 34.8, 140.0, 36.2] (Greater Tokyo area)
# - osaka_area: [134.5, 34.0, 136.0, 35.1] (Osaka area)
# - sapporo_area: [140.9, 42.9, 142.4, 43.5] (Sapporo area)
# - nagoya_area: [136.6, 34.6, 137.4, 35.3] (Nagoya area)
# - fukuoka_area: [129.9, 33.3, 131.0, 34.3] (Fukuoka area)
# - hokkaido_east: [143.0, 42.5, 146.0, 45.5] (Eastern Hokkaido)
# - japan_cloud_free_focused: [122.0, 24.0, 153.0, 46.0] (Japan with cloud cover focus (use 0-10% by default unless user overrides); default cloud_cover_max 10.0)
#
# Special AOI behavior:
# - If the AOI id is "japan_cloud_free_focused" and the user does not provide a cloud constraint,
#   set cloud_cover_max to 10 by default.
#
# Time handling:
#
# - CLEAR expressions MUST be converted into explicit UTC date ranges.
#   Clear expressions include:
#     • “summer 2023”, “winter 2022–2023”
#     • “January 2023”
#     • “2023-06 to 2023-08”
#     • Any phrase with an explicit year and unambiguous boundaries
#
#   When you interpret such expressions, explicitly state the date range you used.
#   Example: “I interpreted ‘summer 2023’ as 2023-06-01 to 2023-08-31 (UTC).”
#
# - AMBIGUOUS expressions MUST trigger clarification.
#   You MUST NOT guess or infer a date range.
#   You MUST NOT call the `search_satellite_scenes` tool until the user provides
#   an explicit start and end date.
#
#   Ambiguous expressions include:
#     • “early <month>”, “mid <month>”, “late <month>”
#     • Relative expressions:
#         “last summer”, “last winter”, “next fall”,
#         “this spring”, “around last year”, etc.
#     • Expressions missing a year:
#         “in August”, “in winter”, “in the summer”, etc.
#     • Any phrasing where the exact year or boundary is unclear
#
# - When asking for clarification due to an ambiguous expression:
#     • DO NOT call the search tool.
#     • Ask the user for an explicit date range.
#     • Provide 2–3 possible example ranges ONLY to help the user select,
#       and explicitly state that these are examples, not assumptions.
#
#       Example:
#       “'late July 2023' is ambiguous and I cannot guess the exact range.
#        Could you specify the exact period you want?
#        For example (only as suggestions):
#          • 2023-07-21 to 2023-07-31
#          • 2023-07-23 to 2023-07-31
#          • 2023-07-25 to 2023-07-31
#        Once you confirm the dates, I can run the search.”
#
#       Example (relative expression):
#       “'last winter' is ambiguous because its meaning depends on the
#        current date. Could you clarify the exact period?
#        For example (only as suggestions):
#          • 2022-12-01 to 2022-02-27
#          • 2023-12-01 to 2023-02-27
#        Or please provide the precise start and end dates.”
#
# - Only AFTER the user provides an explicit start and end date
#   may you construct the datetime_range and call the search tool.
#
#
#
#
# Collections / sensors:
# - In this environment, the `search_satellite_scenes` tool only supports Sentinel-2
#   optical imagery (collection "sentinel-2-l2a").
# - If the user mentions a specific mission or sensor (for example, Sentinel-2, Landsat-8),
#   set the collections field accordingly if supported.
# - If the user mentions Sentinel-1 or other radar missions, explain that this tool
#   does not support those sensors. Do NOT call the search tool with unsupported
#   collections. Propose a reasonable Sentinel-2 alternative instead (for example,
#   "I can search Sentinel-2 optical images over the same area and period; would
#   that work for you?").
# - If the user does not mention any mission, default to ["sentinel-2-l2a"] unless
#   the instructions for this environment say otherwise.
# - If the requested sensor is not available, explain the limitation and propose
#   a reasonable alternative.
#
#
# Cloud cover handling:
# - If the user specifies an explicit threshold like "cloud cover below 10%",
#   set cloud_cover_max to that value.
# - Interpret qualitative phrases as:
#   - "cloud-free" -> cloud_cover_max = 10
#   - "almost cloud-free", "very few clouds" -> cloud_cover_max = 15
#   - "low cloud", "mostly clear" -> cloud_cover_max = 20
# - If the user does not specify cloud cover:
#   - For time ranges of 1 month or shorter, use cloud_cover_max = 30.
#   - For longer time ranges, use cloud_cover_max = 50.
# - If resolve_aoi returns a default_cloud_cover and the user did not specify a
#   cloud constraint, use that default_cloud_cover value as cloud_cover_max.
#
# When answering, briefly explain how you interpreted the time range and
# cloud cover, and mention that cloud cover is based on scene-level metadata
# and may not perfectly match conditions over the user’s exact area of interest.
#
# Presenting results:
# - After the tool returns results, summarize them in a consistent, concise table.
# - Use the following table format unless the user explicitly requests a different format:
#
#   | id | datetime (UTC) | cloud_cover (%) | preview_url |
#   | --- | --- | --- | --- |
#
# - If the user does not specify the number of scenes to return,
#   select the **top 5 scenes** sorted by:
#     1. lowest cloud_cover first,
#     2. then most recent datetime.
#
# - If the user explicitly asks for “best”, “top”, “a few”, “some”, or similar vague requests,
#   still return 5 scenes unless a different number is stated.
#
# - Never list all scenes returned by the tool unless the user explicitly requests a full list.
#
# - For each scene, display:
#     - id
#     - acquisition datetime
#     - cloud_cover
#     - preview_url (or "-" if none exists)
#
# - Do not add extra commentary outside the table unless needed for explanation.
#   After the table, include at most 1–2 sentences summarizing the results.
#
# - Do not fabricate scene IDs or URLs that are not present in the tool output.
#
# - If the tool returns zero scenes:
#     - Clearly state that no scenes were found.
#     - Propose concrete ways to relax constraints (increase cloud cover, expand date range, etc.).
#
# IMPORTANT:
# - When the user specifies a place name, AOI id, region, city, or any geographic hint,
#   you MUST first call the "resolve_aoi" tool.
# - Never infer or construct a bbox directly from your own knowledge or the text of this prompt.
#   Always rely on the output of the "resolve_aoi" tool to obtain the canonical bbox,
#   center coordinates, and any default cloud cover.
# - Only after receiving the result from "resolve_aoi" should you construct a call to
#   "search_satellite_scenes".
#
# When you call the `resolve_aoi` tool:
#
# - If `matched` is true: use the returned `bbox` and proceed to call `search_satellite_scenes`.
# - If `matched` is false: DO NOT call `search_satellite_scenes` yet.
#   Instead, either:
#   - ask the user to provide a bounding box or specific coordinates, OR
#   - propose an approximate bounding box yourself and explicitly ask
#     the user to confirm it before searching.
#
# You map natural language into arguments for the `search_satellite_scenes` tool:
# - bbox: [min_lon, min_lat, max_lon, max_lat]
# - datetime_range: "YYYY-MM-DDTHH:MM:SSZ/YYYY-MM-DDTHH:MM:SSZ"
# - cloud_cover_max: float
# - collections: list of collection ids (e.g. ["sentinel-2-l2a"])
#
# Planning steps:
# 0. ALWAYS start AOI resolution by calling the "resolve_aoi" tool.
#    - Do not directly choose or construct bounding boxes inside the LLM.
#    - Pass the user’s location phrase directly to resolve_aoi.
#    - After the tool returns, extract:
#        aoi_id, bbox, center, note, default_cloud_cover
#    - If resolve_aoi indicates "matched = false", you MUST ask the user for clarification
#      (bbox or coordinates) instead of guessing a bbox.
#
# 1. Identify the user intent: what region, what period, which satellite collections,
#    and what cloud cover constraints they care about.
# 2. Location resolution policy (clarify-first):
#    - After calling resolve_aoi, if matched = true, use the bbox returned by
#      resolve_aoi as the canonical bbox. Do not override it based on your own
#      knowledge or the prompt text.
#    - If resolve_aoi indicates the place is unknown or ambiguous (matched = false),
#      ask for a bbox or coordinates instead of guessing.
#    - If you propose a rough center coordinate, ask for explicit confirmation
#      before calling the search tool.
# 3. Convert natural-language time expressions into an explicit datetime_range,
#    EXCEPT when they contain "early/mid/late <month>".
#
#    - For phrases like "early/mid/late <month>", treat them as ambiguous.
#      You MUST:
#        - ask the user for exact start and end dates, and
#        - NOT call "search_satellite_scenes" until the user provides them.
#
# 4. Map qualitative cloud cover phrases to numeric thresholds using the rules
#    in the system instructions. If AOI id is "japan_cloud_free_focused" and the user
#    did not specify cloud cover, set cloud_cover_max to 10.
# 5. Choose the collection(s).
#    - This environment only supports Sentinel-2 optical imagery via
#      "sentinel-2-l2a". If the user asks for Sentinel-1 or other radar missions,
#      explain that they are not supported by this tool and propose a Sentinel-2
#      alternative instead of calling the search tool.
#    - Use "sentinel-2-l2a" by default, unless the user explicitly asks for
#      another supported sensor (none in this environment).
# 6. Validate the arguments before calling the tool:
#    - bbox has 4 numeric values (min_lon < max_lon, min_lat < max_lat).
#    - datetime_range has valid ISO-8601 timestamps separated by "/".
#    - cloud_cover_max is between 0 and 100.
# 7. Call the tool once with the best-guess parameters.
# 8. Summarize the results in a table with the following columns:
#    id, datetime (UTC), cloud_cover, preview_url.
#    If the user does not specify the number of scenes, return the top 5 scenes.
#
# Examples:
#
# Example 1
# User: "Find cloud-free Sentinel-2 images over eastern Hokkaido in summer 2023."
# Reasoning:
# - First call resolve_aoi("eastern Hokkaido") to resolve the AOI.
#   Suppose resolve_aoi returns:
#     aoi_id = "hokkaido_east"
#     bbox = [143.0, 42.5, 146.0, 45.5]
# - Time: "summer 2023" -> 2023-06-01 to 2023-08-31
# - Collection: Sentinel-2 -> ["sentinel-2-l2a"]
# - Cloud: "cloud-free" -> cloud_cover_max = 10
# Tool call:
# search_satellite_scenes(
#   bbox=[143.0, 42.5, 146.0, 45.5],
#   datetime_range="2023-06-01T00:00:00Z/2023-08-31T23:59:59Z",
#   cloud_cover_max=10.0,
#   collections=["sentinel-2-l2a"],
#   limit=10,
# )
#
# Example 2
# User: "Show me images of Tokyo area in August 2023 with cloud cover below 10%."
# Reasoning:
# - Location: "Tokyo area" -> bbox [138.8, 34.8, 140.0, 36.2]
# - Time: August 2023 -> 2023-08-01 to 2023-08-31
# - Cloud: "below 10%" -> cloud_cover_max = 10
# Tool call:
# search_satellite_scenes(
#   bbox=[138.8, 34.8, 140.0, 36.2],
#   datetime_range="2023-08-01T00:00:00Z/2023-08-31T23:59:59Z",
#   cloud_cover_max=10.0,
#   collections=["sentinel-2-l2a"],
#   limit=10,
# )
#
# Example 3 (missing information)
# User: "Show me cloud-free images."
# Reasoning:
# - Missing both location and time range.
# - Do NOT call the tool yet.
# - Ask a clarifying question such as:
#   "Which area and which time period are you interested in?"
#
#
# Example 5 (ambiguous time + suggestion options)
#
# User: "I need low-cloud Sentinel-2 images of eastern Hokkaido in late July 2023."
#
# Reasoning:
# - "late July 2023" contains "late <month>" and is ambiguous.
# - You MUST NOT guess a date range and MUST NOT call the search tool yet.
# - Offer helpful example ranges so the user can choose.
#
# Correct behavior:
# 1) Call resolve_aoi("eastern Hokkaido").
# 2) If matched = true, ask the user:
#
#    “'late July 2023' is ambiguous.
#      Could you tell me the exact date range you want?
#      For example, do you mean:
#        • 2023-07-21 to 2023-07-31
#        • 2023-07-23 to 2023-07-31
#        • 2023-07-25 to 2023-07-31
#      Once I have the exact range, I can search for low-cloud Sentinel-2 scenes.”
#
# You are an agent. Your internal name is "satellite_stac_agent". The description about you is "Agent to search satellite scenes via STAC based on natural language queries.".
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Show me cloud-free Sentinel-2 images over Japan last summer.\n\n"}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# resolve_aoi: {'location_hint': {'type': <Type.STRING: 'STRING'>}}
# search_satellite_scenes: {'bbox': {'items': {'type': <Type.NUMBER: 'NUMBER'>}, 'type': <Type.ARRAY: 'ARRAY'>}, 'datetime_range': {'type': <Type.STRING: 'STRING'>}, 'cloud_cover_max': {'type': <Type.NUMBER: 'NUMBER'>}, 'limit': {'default': 10, 'type': <Type.INTEGER: 'INTEGER'>}, 'collections': {'items': {'type': <Type.STRING: 'STRING'>}, 'nullable': True, 'type': <Type.ARRAY: 'ARRAY'>}}
# -----------------------------------------------------------
#
# 2025-11-24 15:49:30,753 - INFO - google_llm.py:219 - Response received from the model.
# 2025-11-24 15:49:30,753 - DEBUG - google_llm.py:220 -
# LLM Response:
# -----------------------------------------------------------
# Text:
# Could you please specify the exact date range for "last summer"? As examples:
# * 2023-06-01 to 2023-08-31
# * 2023-07-01 to 2023-09-30
# * 2023-05-01 to 2023-08-31
#
# -----------------------------------------------------------
# Function calls:
#
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Mon, 24 Nov 2025 06:49:30 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=1827","Alt-Svc":"h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"text":"Could you please specify the exact date range for \"last summer\"? As examples:\n* 2023-06-01 to 2023-08-31\n* 2023-07-01 to 2023-09-30\n* 2023-05-01 to 2023-08-31\n"}],"role":"model"},"finish_reason":"STOP","avg_logprobs":-0.10114616933076279}],"model_version":"gemini-2.0-flash","response_id":"-P8jafzgOreT0-kPvaS9wQ8","usage_metadata":{"candidates_token_count":92,"candidates_tokens_details":[{"modality":"TEXT","token_count":92}],"prompt_token_count":5001,"prompt_tokens_details":[{"modality":"TEXT","token_count":5001}],"total_token_count":5093}}
# -----------------------------------------------------------
#
# 2025-11-24 15:49:30,755 - DEBUG - adk_web_server.py:1426 - Generated event in agent run streaming: {"modelVersion":"gemini-2.0-flash","content":{"parts":[{"text":"Could you please specify the exact date range for \"last summer\"? As examples:\n* 2023-06-01 to 2023-08-31\n* 2023-07-01 to 2023-09-30\n* 2023-05-01 to 2023-08-31\n"}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":92,"candidatesTokensDetails":[{"modality":"TEXT","tokenCount":92}],"promptTokenCount":5001,"promptTokensDetails":[{"modality":"TEXT","tokenCount":5001}],"totalTokenCount":5093},"avgLogprobs":-0.10114616933076279,"invocationId":"e-c2cdee62-f76c-4c6f-956c-04704adf2698","author":"satellite_stac_agent","actions":{"stateDelta":{},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"4db909a4-62fd-472a-af11-da3a193019ad","timestamp":1763966968.695784}
# INFO:     127.0.0.1:36062 - "GET /debug/trace/session/e6c825de-e46a-4c9b-aca7-fb0b262769e7 HTTP/1.1" 200 OK
# 2025-11-24 15:50:02,004 - DEBUG - agent_loader.py:322 - Returning cached agent for eval (async)
# INFO:     127.0.0.1:53578 - "POST /apps/eval/eval_sets/normal/add_session HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53578 - "GET /apps/eval/eval_sets/normal/evals HTTP/1.1" 200 OK
# 2025-11-24 15:51:12,024 - INFO - local_eval_sets_manager.py:219 - Creating eval set file `/home/kimura/work/google5days/capstone/src/capstone/scripts/eval/clarification.evalset.json`
# 2025-11-24 15:51:12,024 - INFO - local_eval_sets_manager.py:223 - Eval set file doesn't exist, we will create a new one.
# INFO:     127.0.0.1:33296 - "POST /apps/eval/eval_sets/clarification HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33296 - "GET /apps/eval/eval_sets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33296 - "GET /apps/eval/eval_sets/clarification/evals HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33296 - "GET /apps/eval/users/user/sessions/e6c825de-e46a-4c9b-aca7-fb0b262769e7 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33296 - "GET /debug/trace/session/e6c825de-e46a-4c9b-aca7-fb0b262769e7 HTTP/1.1" 200 OK
# 2025-11-24 15:51:31,098 - INFO - adk_web_server.py:605 - New session created: 5b6467d0-57bb-437c-848c-075a95997734
# INFO:     127.0.0.1:59524 - "POST /apps/eval/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59524 - "GET /apps/eval/users/user/sessions/5b6467d0-57bb-437c-848c-075a95997734 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59524 - "GET /debug/trace/session/5b6467d0-57bb-437c-848c-075a95997734 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59524 - "GET /apps/eval/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59524 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-24 15:51:32,762 - INFO - google_llm.py:163 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-24 15:51:32,762 - DEBUG - google_llm.py:169 -
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are a satellite metadata search agent. You translate natural language queries
# into STAC search parameters and call the `search_satellite_scenes` tool.
#
# Your primary goal is to help the user find suitable Earth observation scenes
# by converting natural language queries into precise STAC search parameters
# and by clearly explaining the search results.
#
# You have access to two tools:
# - "resolve_aoi": maps a location hint or AOI id to a canonical AOI (bbox, center, note, default cloud cover).
# - "search_satellite_scenes": queries a STAC API for scenes.
#
# The search tool expects the following arguments:
# - bbox: [min_lon, min_lat, max_lon, max_lat]
# - datetime_range: ISO 8601 interval string "start/end" (UTC)
# - cloud_cover_max: maximum allowed cloud cover in percent (0–100)
# - limit (optional): maximum number of scenes to return
# - collections (optional): list of STAC collection IDs, e.g. ["sentinel-2-l2a"]
#
# Tool usage:
# - When you have enough information to perform a search, call the "search_satellite_scenes" tool
#   with carefully constructed arguments.
# - Do not invent fields or change the tool schema; always respect the defined input schema.
# - Validate arguments logically before calling the tool (for example, start date must be before
#   end date, bbox must have min_lon < max_lon and min_lat < max_lat).
# - If user constraints are impossible or inconsistent, ask for clarification instead of
#   calling the tool with invalid parameters.
#
# General behavior:
# - Always aim to return scenes that match the user's intent as closely as possible.
# - Prefer asking clarification questions over guessing when the user query is ambiguous
#   (for example, vague locations like "northern Europe" or vague times like "last winter").
# - Be explicit about any assumptions you make (for example, the exact date range you chose
#   for "summer 2023" or the approximate bounding box used for a named region).
# - If the tool returns no results, try to reason about why (too strict cloud_cover,
#   too short time range, too small area, wrong collection) and propose concrete ways
#   to relax or adjust the constraints.
#
# Location handling (clarify-first):
# - If the user provides an explicit bounding box, use it directly.
# - Otherwise, ALWAYS call the "resolve_aoi" tool first when the user mentions
#   a place name, AOI id, region, or city. Use the canonical bbox and any default
#   cloud cover returned by resolve_aoi.
# - If you do not recognize the place name (resolve_aoi matched = false), first
#   ask the user for a location or coordinates instead of guessing a bbox.
# - If you have a reasonable guess of the approximate area, propose a center
#   coordinate and ask for confirmation before calling the search tool. Example:
#   "I can search around lon X, lat Y; is that okay? If not, please provide a bbox."
# - Use known AOI IDs exactly as listed below. Do not invent new AOI IDs.
# - Never fabricate impossible coordinates. Longitudes must be in [-180, 180],
#   latitudes in [-90, 90].
#
#
# Known AOIs (use these bounding boxes when the phrase matches exactly):
# - japan: [122.0, 24.0, 153.0, 46.0] (Japan main islands)
# - usa_mainland: [-125.0, 24.0, -66.5, 49.5] (Contiguous United States)
# - united_kingdom: [-8.0, 49.5, 2.5, 59.0] (United Kingdom)
# - france: [-5.5, 41.0, 9.8, 51.5] (France)
# - germany: [5.5, 47.0, 15.5, 55.5] (Germany)
# - tokyo_area: [138.8, 34.8, 140.0, 36.2] (Greater Tokyo area)
# - osaka_area: [134.5, 34.0, 136.0, 35.1] (Osaka area)
# - sapporo_area: [140.9, 42.9, 142.4, 43.5] (Sapporo area)
# - nagoya_area: [136.6, 34.6, 137.4, 35.3] (Nagoya area)
# - fukuoka_area: [129.9, 33.3, 131.0, 34.3] (Fukuoka area)
# - hokkaido_east: [143.0, 42.5, 146.0, 45.5] (Eastern Hokkaido)
# - japan_cloud_free_focused: [122.0, 24.0, 153.0, 46.0] (Japan with cloud cover focus (use 0-10% by default unless user overrides); default cloud_cover_max 10.0)
#
# Special AOI behavior:
# - If the AOI id is "japan_cloud_free_focused" and the user does not provide a cloud constraint,
#   set cloud_cover_max to 10 by default.
#
# Time handling:
#
# - CLEAR expressions MUST be converted into explicit UTC date ranges.
#   Clear expressions include:
#     • “summer 2023”, “winter 2022–2023”
#     • “January 2023”
#     • “2023-06 to 2023-08”
#     • Any phrase with an explicit year and unambiguous boundaries
#
#   When you interpret such expressions, explicitly state the date range you used.
#   Example: “I interpreted ‘summer 2023’ as 2023-06-01 to 2023-08-31 (UTC).”
#
# - AMBIGUOUS expressions MUST trigger clarification.
#   You MUST NOT guess or infer a date range.
#   You MUST NOT call the `search_satellite_scenes` tool until the user provides
#   an explicit start and end date.
#
#   Ambiguous expressions include:
#     • “early <month>”, “mid <month>”, “late <month>”
#     • Relative expressions:
#         “last summer”, “last winter”, “next fall”,
#         “this spring”, “around last year”, etc.
#     • Expressions missing a year:
#         “in August”, “in winter”, “in the summer”, etc.
#     • Any phrasing where the exact year or boundary is unclear
#
# - When asking for clarification due to an ambiguous expression:
#     • DO NOT call the search tool.
#     • Ask the user for an explicit date range.
#     • Provide 2–3 possible example ranges ONLY to help the user select,
#       and explicitly state that these are examples, not assumptions.
#
#       Example:
#       “'late July 2023' is ambiguous and I cannot guess the exact range.
#        Could you specify the exact period you want?
#        For example (only as suggestions):
#          • 2023-07-21 to 2023-07-31
#          • 2023-07-23 to 2023-07-31
#          • 2023-07-25 to 2023-07-31
#        Once you confirm the dates, I can run the search.”
#
#       Example (relative expression):
#       “'last winter' is ambiguous because its meaning depends on the
#        current date. Could you clarify the exact period?
#        For example (only as suggestions):
#          • 2022-12-01 to 2022-02-27
#          • 2023-12-01 to 2023-02-27
#        Or please provide the precise start and end dates.”
#
# - Only AFTER the user provides an explicit start and end date
#   may you construct the datetime_range and call the search tool.
#
#
#
#
# Collections / sensors:
# - In this environment, the `search_satellite_scenes` tool only supports Sentinel-2
#   optical imagery (collection "sentinel-2-l2a").
# - If the user mentions a specific mission or sensor (for example, Sentinel-2, Landsat-8),
#   set the collections field accordingly if supported.
# - If the user mentions Sentinel-1 or other radar missions, explain that this tool
#   does not support those sensors. Do NOT call the search tool with unsupported
#   collections. Propose a reasonable Sentinel-2 alternative instead (for example,
#   "I can search Sentinel-2 optical images over the same area and period; would
#   that work for you?").
# - If the user does not mention any mission, default to ["sentinel-2-l2a"] unless
#   the instructions for this environment say otherwise.
# - If the requested sensor is not available, explain the limitation and propose
#   a reasonable alternative.
#
#
# Cloud cover handling:
# - If the user specifies an explicit threshold like "cloud cover below 10%",
#   set cloud_cover_max to that value.
# - Interpret qualitative phrases as:
#   - "cloud-free" -> cloud_cover_max = 10
#   - "almost cloud-free", "very few clouds" -> cloud_cover_max = 15
#   - "low cloud", "mostly clear" -> cloud_cover_max = 20
# - If the user does not specify cloud cover:
#   - For time ranges of 1 month or shorter, use cloud_cover_max = 30.
#   - For longer time ranges, use cloud_cover_max = 50.
# - If resolve_aoi returns a default_cloud_cover and the user did not specify a
#   cloud constraint, use that default_cloud_cover value as cloud_cover_max.
#
# When answering, briefly explain how you interpreted the time range and
# cloud cover, and mention that cloud cover is based on scene-level metadata
# and may not perfectly match conditions over the user’s exact area of interest.
#
# Presenting results:
# - After the tool returns results, summarize them in a consistent, concise table.
# - Use the following table format unless the user explicitly requests a different format:
#
#   | id | datetime (UTC) | cloud_cover (%) | preview_url |
#   | --- | --- | --- | --- |
#
# - If the user does not specify the number of scenes to return,
#   select the **top 5 scenes** sorted by:
#     1. lowest cloud_cover first,
#     2. then most recent datetime.
#
# - If the user explicitly asks for “best”, “top”, “a few”, “some”, or similar vague requests,
#   still return 5 scenes unless a different number is stated.
#
# - Never list all scenes returned by the tool unless the user explicitly requests a full list.
#
# - For each scene, display:
#     - id
#     - acquisition datetime
#     - cloud_cover
#     - preview_url (or "-" if none exists)
#
# - Do not add extra commentary outside the table unless needed for explanation.
#   After the table, include at most 1–2 sentences summarizing the results.
#
# - Do not fabricate scene IDs or URLs that are not present in the tool output.
#
# - If the tool returns zero scenes:
#     - Clearly state that no scenes were found.
#     - Propose concrete ways to relax constraints (increase cloud cover, expand date range, etc.).
#
# IMPORTANT:
# - When the user specifies a place name, AOI id, region, city, or any geographic hint,
#   you MUST first call the "resolve_aoi" tool.
# - Never infer or construct a bbox directly from your own knowledge or the text of this prompt.
#   Always rely on the output of the "resolve_aoi" tool to obtain the canonical bbox,
#   center coordinates, and any default cloud cover.
# - Only after receiving the result from "resolve_aoi" should you construct a call to
#   "search_satellite_scenes".
#
# When you call the `resolve_aoi` tool:
#
# - If `matched` is true: use the returned `bbox` and proceed to call `search_satellite_scenes`.
# - If `matched` is false: DO NOT call `search_satellite_scenes` yet.
#   Instead, either:
#   - ask the user to provide a bounding box or specific coordinates, OR
#   - propose an approximate bounding box yourself and explicitly ask
#     the user to confirm it before searching.
#
# You map natural language into arguments for the `search_satellite_scenes` tool:
# - bbox: [min_lon, min_lat, max_lon, max_lat]
# - datetime_range: "YYYY-MM-DDTHH:MM:SSZ/YYYY-MM-DDTHH:MM:SSZ"
# - cloud_cover_max: float
# - collections: list of collection ids (e.g. ["sentinel-2-l2a"])
#
# Planning steps:
# 0. ALWAYS start AOI resolution by calling the "resolve_aoi" tool.
#    - Do not directly choose or construct bounding boxes inside the LLM.
#    - Pass the user’s location phrase directly to resolve_aoi.
#    - After the tool returns, extract:
#        aoi_id, bbox, center, note, default_cloud_cover
#    - If resolve_aoi indicates "matched = false", you MUST ask the user for clarification
#      (bbox or coordinates) instead of guessing a bbox.
#
# 1. Identify the user intent: what region, what period, which satellite collections,
#    and what cloud cover constraints they care about.
# 2. Location resolution policy (clarify-first):
#    - After calling resolve_aoi, if matched = true, use the bbox returned by
#      resolve_aoi as the canonical bbox. Do not override it based on your own
#      knowledge or the prompt text.
#    - If resolve_aoi indicates the place is unknown or ambiguous (matched = false),
#      ask for a bbox or coordinates instead of guessing.
#    - If you propose a rough center coordinate, ask for explicit confirmation
#      before calling the search tool.
# 3. Convert natural-language time expressions into an explicit datetime_range,
#    EXCEPT when they contain "early/mid/late <month>".
#
#    - For phrases like "early/mid/late <month>", treat them as ambiguous.
#      You MUST:
#        - ask the user for exact start and end dates, and
#        - NOT call "search_satellite_scenes" until the user provides them.
#
# 4. Map qualitative cloud cover phrases to numeric thresholds using the rules
#    in the system instructions. If AOI id is "japan_cloud_free_focused" and the user
#    did not specify cloud cover, set cloud_cover_max to 10.
# 5. Choose the collection(s).
#    - This environment only supports Sentinel-2 optical imagery via
#      "sentinel-2-l2a". If the user asks for Sentinel-1 or other radar missions,
#      explain that they are not supported by this tool and propose a Sentinel-2
#      alternative instead of calling the search tool.
#    - Use "sentinel-2-l2a" by default, unless the user explicitly asks for
#      another supported sensor (none in this environment).
# 6. Validate the arguments before calling the tool:
#    - bbox has 4 numeric values (min_lon < max_lon, min_lat < max_lat).
#    - datetime_range has valid ISO-8601 timestamps separated by "/".
#    - cloud_cover_max is between 0 and 100.
# 7. Call the tool once with the best-guess parameters.
# 8. Summarize the results in a table with the following columns:
#    id, datetime (UTC), cloud_cover, preview_url.
#    If the user does not specify the number of scenes, return the top 5 scenes.
#
# Examples:
#
# Example 1
# User: "Find cloud-free Sentinel-2 images over eastern Hokkaido in summer 2023."
# Reasoning:
# - First call resolve_aoi("eastern Hokkaido") to resolve the AOI.
#   Suppose resolve_aoi returns:
#     aoi_id = "hokkaido_east"
#     bbox = [143.0, 42.5, 146.0, 45.5]
# - Time: "summer 2023" -> 2023-06-01 to 2023-08-31
# - Collection: Sentinel-2 -> ["sentinel-2-l2a"]
# - Cloud: "cloud-free" -> cloud_cover_max = 10
# Tool call:
# search_satellite_scenes(
#   bbox=[143.0, 42.5, 146.0, 45.5],
#   datetime_range="2023-06-01T00:00:00Z/2023-08-31T23:59:59Z",
#   cloud_cover_max=10.0,
#   collections=["sentinel-2-l2a"],
#   limit=10,
# )
#
# Example 2
# User: "Show me images of Tokyo area in August 2023 with cloud cover below 10%."
# Reasoning:
# - Location: "Tokyo area" -> bbox [138.8, 34.8, 140.0, 36.2]
# - Time: August 2023 -> 2023-08-01 to 2023-08-31
# - Cloud: "below 10%" -> cloud_cover_max = 10
# Tool call:
# search_satellite_scenes(
#   bbox=[138.8, 34.8, 140.0, 36.2],
#   datetime_range="2023-08-01T00:00:00Z/2023-08-31T23:59:59Z",
#   cloud_cover_max=10.0,
#   collections=["sentinel-2-l2a"],
#   limit=10,
# )
#
# Example 3 (missing information)
# User: "Show me cloud-free images."
# Reasoning:
# - Missing both location and time range.
# - Do NOT call the tool yet.
# - Ask a clarifying question such as:
#   "Which area and which time period are you interested in?"
#
#
# Example 5 (ambiguous time + suggestion options)
#
# User: "I need low-cloud Sentinel-2 images of eastern Hokkaido in late July 2023."
#
# Reasoning:
# - "late July 2023" contains "late <month>" and is ambiguous.
# - You MUST NOT guess a date range and MUST NOT call the search tool yet.
# - Offer helpful example ranges so the user can choose.
#
# Correct behavior:
# 1) Call resolve_aoi("eastern Hokkaido").
# 2) If matched = true, ask the user:
#
#    “'late July 2023' is ambiguous.
#      Could you tell me the exact date range you want?
#      For example, do you mean:
#        • 2023-07-21 to 2023-07-31
#        • 2023-07-23 to 2023-07-31
#        • 2023-07-25 to 2023-07-31
#      Once I have the exact range, I can search for low-cloud Sentinel-2 scenes.”
#
# You are an agent. Your internal name is "satellite_stac_agent". The description about you is "Agent to search satellite scenes via STAC based on natural language queries.".
# -----------------------------------------------------------
# Config:
# {'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Show me cloud-free Sentinel-2 images over eastern Hokkaido."}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# resolve_aoi: {'location_hint': {'type': <Type.STRING: 'STRING'>}}
# search_satellite_scenes: {'bbox': {'items': {'type': <Type.NUMBER: 'NUMBER'>}, 'type': <Type.ARRAY: 'ARRAY'>}, 'datetime_range': {'type': <Type.STRING: 'STRING'>}, 'cloud_cover_max': {'type': <Type.NUMBER: 'NUMBER'>}, 'limit': {'default': 10, 'type': <Type.INTEGER: 'INTEGER'>}, 'collections': {'items': {'type': <Type.STRING: 'STRING'>}, 'nullable': True, 'type': <Type.ARRAY: 'ARRAY'>}}
# -----------------------------------------------------------
#
# 2025-11-24 15:51:34,426 - INFO - google_llm.py:219 - Response received from the model.
# 2025-11-24 15:51:34,427 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2025-11-24 15:51:34,427 - DEBUG - google_llm.py:220 -
# LLM Response:
# -----------------------------------------------------------
# Text:
# None
# -----------------------------------------------------------
# Function calls:
# name: resolve_aoi, args: {'location_hint': 'eastern Hokkaido'}
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Mon, 24 Nov 2025 06:51:34 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=1567","Alt-Svc":"h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"function_call":{"args":{"location_hint":"eastern Hokkaido"},"name":"resolve_aoi"}}],"role":"model"},"finish_reason":"STOP","avg_logprobs":-0.25468020968967015}],"model_version":"gemini-2.0-flash","response_id":"dAAkadnKN7qQ0-kP_7amiA8","usage_metadata":{"candidates_token_count":9,"candidates_tokens_details":[{"modality":"TEXT","token_count":9}],"prompt_token_count":4999,"prompt_tokens_details":[{"modality":"TEXT","token_count":4999}],"total_token_count":5008}}
# -----------------------------------------------------------
#
# 2025-11-24 15:51:34,428 - DEBUG - adk_web_server.py:1426 - Generated event in agent run streaming: {"modelVersion":"gemini-2.0-flash","content":{"parts":[{"functionCall":{"id":"adk-6f777c72-32fd-4e09-b097-2bf2d71bde37","args":{"location_hint":"eastern Hokkaido"},"name":"resolve_aoi"}}],"role":"model"},"finishReason":"STOP","usageMetadata":{"candidatesTokenCount":9,"candidatesTokensDetails":[{"modality":"TEXT","tokenCount":9}],"promptTokenCount":4999,"promptTokensDetails":[{"modality":"TEXT","tokenCount":4999}],"totalTokenCount":5008},"avgLogprobs":-0.25468020968967015,"invocationId":"e-ba9a7af7-f480-4e85-88be-4f3d52a0ce87","author":"satellite_stac_agent","actions":{"stateDelta":{},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"longRunningToolIds":[],"id":"06d64979-579a-4854-901a-b77b9f203c52","timestamp":1763967092.71291}
# 2025-11-24 15:51:34,431 - DEBUG - adk_web_server.py:1426 - Generated event in agent run streaming: {"content":{"parts":[{"functionResponse":{"id":"adk-6f777c72-32fd-4e09-b097-2bf2d71bde37","name":"resolve_aoi","response":{"matched":true,"aoi_id":"hokkaido_east","bbox":[143.0,42.5,146.0,45.5],"center":{"lon":144.5,"lat":44.0},"note":"Eastern Hokkaido","default_cloud_cover":null,"message":"Matched known AOI."}}}],"role":"user"},"invocationId":"e-ba9a7af7-f480-4e85-88be-4f3d52a0ce87","author":"satellite_stac_agent","actions":{"stateDelta":{},"artifactDelta":{},"requestedAuthConfigs":{},"requestedToolConfirmations":{}},"id":"54926739-9fef-4778-b3e8-65b7dcf4c092","timestamp":1763967094.430529}
# 2025-11-24 15:51:34,491 - INFO - google_llm.py:163 - Sending out request, model: gemini-2.0-flash, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-24 15:51:34,491 - DEBUG - google_llm.py:169 -
# LLM Request:
# -----------------------------------------------------------
# System Instruction:
# You are a satellite metadata search agent. You translate natural language queries
# into STAC search parameters and call the `search_satellite_scenes` tool.
#
# Your primary goal is to help the user find suitable Earth observation scenes
# by converting natural language queries into precise STAC search parameters
# and by clearly explaining the search results.
#
# You have access to two tools:
# - "resolve_aoi": maps a location hint or AOI id to a canonical AOI (bbox, center, note, default cloud cover).
# - "search_satellite_scenes": queries a STAC API for scenes.
#
# The search tool expects the following arguments:
# - bbox: [min_lon, min_lat, max_lon, max_lat]
# - datetime_range: ISO 8601 interval string "start/end" (UTC)
# - cloud_cover_max: maximum allowed cloud cover in percent (0–100)
# - limit (optional): maximum number of scenes to return
# - collections (optional): list of STAC collection IDs, e.g. ["sentinel-2-l2a"]
#
# Tool usage:
# - When you have enough information to perform a search, call the "search_satellite_scenes" tool
#   with carefully constructed arguments.
# - Do not invent fields or change the tool schema; always respect the defined input schema.
# - Validate arguments logically before calling the tool (for example, start date must be before
#   end date, bbox must have min_lon < max_lon and min_lat < max_lat).
# - If user constraints are impossible or inconsistent, ask for clarification instead of
#   calling the tool with invalid parameters.
#
# General behavior:
# - Always aim to return scenes that match the user's intent as closely as possible.
# - Prefer asking clarification questions over guessing when the user query is ambiguous
#   (for example, vague locations like "northern Europe" or vague times like "last winter").
# - Be explicit about any assumptions you make (for example, the exact date range you chose
#   for "summer 2023" or the approximate bounding box used for a named region).
# - If the tool returns no results, try to reason about why (too strict cloud_cover,
#   too short time range, too small area, wrong collection) and propose concrete ways
#   to relax or adjust the constraints.
#
# Location handling (clarify-first):
# - If the user provides an explicit bounding box, use it directly.
# - Otherwise, ALWAYS call the "resolve_aoi" tool first when the user mentions
#   a place name, AOI id, region, or city. Use the canonical bbox and any default
#   cloud cover returned by resolve_aoi.
# - If you do not recognize the place name (resolve_aoi matched = false), first
#   ask the user for a location or coordinates instead of guessing a bbox.
# - If you have a reasonable guess of the approximate area, propose a center
#   coordinate and ask for confirmation before calling the search tool. Example:
#   "I can search around lon X, lat Y; is that okay? If not, please provide a bbox."
# - Use known AOI IDs exactly as listed below. Do not invent new AOI IDs.
# - Never fabricate impossible coordinates. Longitudes must be in [-180, 180],
#   latitudes in [-90, 90].
#
#
# Known AOIs (use these bounding boxes when the phrase matches exactly):
# - japan: [122.0, 24.0, 153.0, 46.0] (Japan main islands)
# - usa_mainland: [-125.0, 24.0, -66.5, 49.5] (Contiguous United States)
# - united_kingdom: [-8.0, 49.5, 2.5, 59.0] (United Kingdom)
# - france: [-5.5, 41.0, 9.8, 51.5] (France)
# - germany: [5.5, 47.0, 15.5, 55.5] (Germany)
# - tokyo_area: [138.8, 34.8, 140.0, 36.2] (Greater Tokyo area)
# - osaka_area: [134.5, 34.0, 136.0, 35.1] (Osaka area)
# - sapporo_area: [140.9, 42.9, 142.4, 43.5] (Sapporo area)
# - nagoya_area: [136.6, 34.6, 137.4, 35.3] (Nagoya area)
# - fukuoka_area: [129.9, 33.3, 131.0, 34.3] (Fukuoka area)
# - hokkaido_east: [143.0, 42.5, 146.0, 45.5] (Eastern Hokkaido)
# - japan_cloud_free_focused: [122.0, 24.0, 153.0, 46.0] (Japan with cloud cover focus (use 0-10% by default unless user overrides); default cloud_cover_max 10.0)
#
# Special AOI behavior:
# - If the AOI id is "japan_cloud_free_focused" and the user does not provide a cloud constraint,
#   set cloud_cover_max to 10 by default.
#
# Time handling:
#
# - CLEAR expressions MUST be converted into explicit UTC date ranges.
#   Clear expressions include:
#     • “summer 2023”, “winter 2022–2023”
#     • “January 2023”
#     • “2023-06 to 2023-08”
#     • Any phrase with an explicit year and unambiguous boundaries
#
#   When you interpret such expressions, explicitly state the date range you used.
#   Example: “I interpreted ‘summer 2023’ as 2023-06-01 to 2023-08-31 (UTC).”
#
# - AMBIGUOUS expressions MUST trigger clarification.
#   You MUST NOT guess or infer a date range.
#   You MUST NOT call the `search_satellite_scenes` tool until the user provides
#   an explicit start and end date.
#
#   Ambiguous expressions include:
#     • “early <month>”, “mid <month>”, “late <month>”
#     • Relative expressions:
#         “last summer”, “last winter”, “next fall”,
#         “this spring”, “around last year”, etc.
#     • Expressions missing a year:
#         “in August”, “in winter”, “in the summer”, etc.
# ...
#        For example (only as suggestions):
#          • 2022-12-01 to 2022-02-27
#          • 2023-12-01 to 2023-02-27
#        Or please provide the precise start and end dates.”
#
# - Only AFTER the user provides an explicit start and end date
#   may you construct the datetime_range and call the search tool.
#
#
#
#
# Collections / sensors:
# - In this environment, the `search_satellite_scenes` tool only supports Sentinel-2
#   optical imagery (collection "sentinel-2-l2a").
# - If the user mentions a specific mission or sensor (for example, Sentinel-2, Landsat-8),
#   set the collections field accordingly if supported.
# - If the user mentions Sentinel-1 or other radar missions, explain that this tool
#   does not support those sensors. Do NOT call the search tool with unsupported
#   collections. Propose a reasonable Sentinel-2 alternative instead (for example,
#   "I can search Sentinel-2 optical images over the same area and period; would
#   that work for you?").
# - If the user does not mention any mission, default to ["sentinel-2-l2a"] unless
#   the instructions for this environment say otherwise.
# - If the requested sensor is not available, explain the limitation and propose
#   a reasonable alternative.
#
#
# Cloud cover handling:
# - If the user specifies an explicit threshold like "cloud cover below 10%",
#   set cloud_cover_max to that value.
# - Interpret qualitative phrases as:
#   - "cloud-free" -> cloud_cover_max = 10
#   - "almost cloud-free", "very few clouds" -> cloud_cover_max = 15
#   - "low cloud", "mostly clear" -> cloud_cover_max = 20
# - If the user does not specify cloud cover:
#   - For time ranges of 1 month or shorter, use cloud_cover_max = 30.
#   - For longer time ranges, use cloud_cover_max = 50.
# - If resolve_aoi returns a default_cloud_cover and the user did not specify a
#   cloud constraint, use that default_cloud_cover value as cloud_cover_max.
#
# When answering, briefly explain how you interpreted the time range and
# cloud cover, and mention that cloud cover is based on scene-level metadata
# and may not perfectly match conditions over the user’s exact area of interest.
#
# Presenting results:
# - After the tool returns results, summarize them in a consistent, concise table.
# - Use the following table format unless the user explicitly requests a different format:
#
#   | id | datetime (UTC) | cloud_cover (%) | preview_url |
#   | --- | --- | --- | --- |
#
# - If the user does not specify the number of scenes to return,
#   select the **top 5 scenes** sorted by:
#     1. lowest cloud_cover first,
#     2. then most recent datetime.
#
# - If the user explicitly asks for “best”, “top”, “a few”, “some”, or similar vague requests,
#   still return 5 scenes unless a different number is stated.
#
# - Never list all scenes returned by the tool unless the user explicitly requests a full list.
#
# - For each scene, display:
#     - id
#     - acquisition datetime
#     - cloud_cover
#     - preview_url (or "-" if none exists)
#
# - Do not add extra commentary outside the table unless needed for explanation.
#   After the table, include at most 1–2 sentences summarizing the results.
#
# - Do not fabricate scene IDs or URLs that are not present in the tool output.
#
# - If the tool returns zero scenes:
#     - Clearly state that no scenes were found.
#     - Propose concrete ways to relax constraints (increase cloud cover, expand date range, etc.).
#
# IMPORTANT:
# - When the user specifies a place name, AOI id, region, city, or any geographic hint,
#   you MUST first call the "resolve_aoi" tool.
# - Never infer or construct a bbox directly from your own knowledge or the text of this prompt.
#   Always rely on the output of the "resolve_aoi" tool to obtain the canonical bbox,
#   center coordinates, and any default cloud cover.
# - Only after receiving the result from "resolve_aoi" should you construct a call to
#   "search_satellite_scenes".
#
# When you call the `resolve_aoi` tool:
#
# - If `matched` is true: use the returned `bbox` and proceed to call `search_satellite_scenes`.
# - If `matched` is false: DO NOT call `search_satellite_scenes` yet.
#   Instead, either:
#   - ask the user to provide a bounding box or specific coordinates, OR
#   - propose an approximate bounding box yourself and explicitly ask
#     the user to confirm it before searching.
#
# You map natural language into arguments for the `search_satellite_scenes` tool:
# - bbox: [min_lon, min_lat, max_lon, max_lat]
# - datetime_range: "YYYY-MM-DDTHH:MM:SSZ/YYYY-MM-DDTHH:MM:SSZ"
# - cloud_cover_max: float
# - collections: list of collection ids (e.g. ["sentinel-2-l2a"])
#
# Planning steps:
# 0. ALWAYS start AOI resolution by calling the "resolve_aoi" tool.
#    - Do not directly choose or construct bounding boxes inside the LLM.
#    - Pass the user’s location phrase directly to resolve_aoi.
#    - After the tool returns, extract:
#        aoi_id, bbox, center, note, default_cloud_cover
#    - If resolve_aoi indicates "matched = false", you MUST ask the user for clarification
#      (bbox or coordinates) instead of guessing a bbox.
#
# 1. Identify the user intent: what region, what period, which satellite collections,
#    and what cloud cover constraints they care about.
# 2. Location resolution policy (clarify-first):
#    - After calling resolve_aoi, if matched = true, use the bbox returned by
#      resolve_aoi as the canonical bbox. Do not override it based on your own
#      knowledge or the prompt text.
#    - If resolve_aoi indicates the place is unknown or ambiguous (matched = false),
#      ask for a bbox or coordinates instead of guessing.
#    - If you propose a rough center coordinate, ask for explicit confirmation
#      before calling the search tool.
# 3. Convert natural-language time expressions into an explicit datetime_range,
#    EXCEPT when they contain "early/mid/late <month>".
#
#    - For phrases like "early/mid/late <month>", treat them as ambiguous.
#      You MUST:
#        - ask the user for exact start and end dates, and
#        - NOT call "search_satellite_scenes" until the user provides them.
#
# 4. Map qualitative cloud cover phrases to numeric thresholds using the rules
#    in the system instructions. If AOI id is "japan_cloud_free_focused" and the user
#    did not specify cloud cover, set cloud_cover_max to 10.
# 5. Choose the collection(s).
#    - This environment only supports Sentinel-2 optical imagery via
#      "sentinel-2-l2a". If the user asks for Sentinel-1 or other radar missions,
#      explain that they are not supported by this tool and propose a Sentinel-2
#      alternative instead of calling the search tool.
#    - Use "sentinel-2-l2a" by default, unless the user explicitly asks for
#      another supported sensor (none in this environment).
# 6. Validate the arguments before calling the tool:
#    - bbox has 4 numeric values (min_lon < max_lon, min_lat < max_lat).
#    - datetime_range has valid ISO-8601 timestamps separated by "/".
#    - cloud_cover_max is between 0 and 100.
# 7. Call the tool once with the best-guess parameters.
# 8. Summarize the results in a table with the following columns:
#    id, datetime (UTC), cloud_cover, preview_url.
#    If the user does not specify the number of scenes, return the top 5 scenes.
#
# Examples:
#
# Example 1
# User: "Find cloud-free Sentinel-2 images over eastern Hokkaido in summer 2023."
# Reasoning:
# - First call resolve_aoi("eastern Hokkaido") to resolve the AOI.
#   Suppose resolve_aoi returns:
#     aoi_id = "hokkaido_east"
#     bbox = [143.0, 42.5, 146.0, 45.5]
# - Time: "summer 2023" -> 2023-06-01 to 2023-08-31
# - Collection: Sentinel-2 -> ["sentinel-2-l2a"]
# - Cloud: "cloud-free" -> cloud_cover_max = 10
# Tool call:
# search_satellite_scenes(
#   bbox=[143.0, 42.5, 146.0, 45.5],
#   datetime_range="2023-06-01T00:00:00Z/2023-08-31T23:59:59Z",
#   cloud_cover_max=10.0,
#   collections=["sentinel-2-l2a"],
#   limit=10,
# )
#
# Example 2
# User: "Show me images of Tokyo area in August 2023 with cloud cover below 10%."
# Reasoning:
# - Location: "Tokyo area" -> bbox [138.8, 34.8, 140.0, 36.2]
# - Time: August 2023 -> 2023-08-01 to 2023-08-31
# - Cloud: "below 10%" -> cloud_cover_max = 10
# Tool call:
# search_satellite_scenes(
#   bbox=[138.8, 34.8, 140.0, 36.2],
#   datetime_range="2023-08-01T00:00:00Z/2023-08-31T23:59:59Z",
#   cloud_cover_max=10.0,
#   collections=["sentinel-2-l2a"],
#   limit=10,
# )
#
# Example 3 (missing information)
# User: "Show me cloud-free images."
# Reasoning:
# - Missing both location and time range.
# - Do NOT call the tool yet.
# - Ask a clarifying question such as:
#   "Which area and which time period are you interested in?"
#
#
# Example 5 (ambiguous time + suggestion options)
#
# User: "I need low-cloud Sentinel-2 images of eastern Hokkaido in late July 2023."
#
# Reasoning:
# - "late July 2023" contains "late <month>" and is ambiguous.
# - You MUST NOT guess a date range and MUST NOT call the search tool yet.
# - Offer helpful example ranges so the user can choose.
#
# Correct behavior:
# 1) Call resolve_aoi("eastern Hokkaido").
# 2) If matched = true, ask the user:
#
#    “'late July 2023' is ambiguous.
#      Could you tell me the exact date range you want?
#      For example, do you mean:
#        • 2023-07-21 to 2023-07-31
#        • 2023-07-23 to 2023-07-31
#        • 2023-07-25 to 2023-07-31
#      Once I have the exact range, I can search for low-cloud Sentinel-2 scenes.”
#
# You are an agent. Your internal name is "satellite_stac_agent". The description about you is "Agent to search satellite scenes via STAC based on natural language queries.".
# -----------------------------------------------------------
# Config:
# {'http_options': {'retry_options': {'attempts': 7, 'initial_delay': 5.0, 'max_delay': 120.0, 'exp_base': 2.0, 'http_status_codes': [408, 429, 500, 502, 503, 504]}}, 'tools': [{}]}
# -----------------------------------------------------------
# Contents:
# {"parts":[{"text":"Find Sentinel-1 radar images over eastern Hokkaido in January 2023 with low cloud cover.\n"}],"role":"user"}
# -----------------------------------------------------------
# Functions:
# resolve_aoi: {'location_hint': {'type': <Type.STRING: 'STRING'>}}
# search_satellite_scenes: {'bbox': {'items': {'type': <Type.NUMBER: 'NUMBER'>}, 'type': <Type.ARRAY: 'ARRAY'>}, 'datetime_range': {'type': <Type.STRING: 'STRING'>}, 'cloud_cover_max': {'type': <Type.NUMBER: 'NUMBER'>}, 'limit': {'default': 10, 'type': <Type.INTEGER: 'INTEGER'>}, 'collections': {'items': {'type': <Type.STRING: 'STRING'>}, 'nullable': True, 'type': <Type.ARRAY: 'ARRAY'>}}
# -----------------------------------------------------------
#
# 2025-11-24 15:56:12,999 - INFO - google_llm.py:219 - Response received from the model.
# 2025-11-24 15:56:12,999 - DEBUG - google_llm.py:220 -
# LLM Response:
# -----------------------------------------------------------
# Text:
# This tool can only search for optical imagery, and does not support radar sensors such as Sentinel-1.
#
# However, I can search for Sentinel-2 optical images over the same area and period; would that work for you? I will use a cloud cover maximum of 20% to match your "low cloud cover" request.
#
# -----------------------------------------------------------
# Function calls:
#
# -----------------------------------------------------------
# Raw response:
# {"sdk_http_response":{"headers":{"Content-Type":"application/json; charset=UTF-8","Vary":"Origin, X-Origin, Referer","Content-Encoding":"gzip","Date":"Mon, 24 Nov 2025 06:56:12 GMT","Server":"scaffolding on HTTPServer2","X-XSS-Protection":"0","X-Frame-Options":"SAMEORIGIN","X-Content-Type-Options":"nosniff","Server-Timing":"gfet4t7; dur=2447","Alt-Svc":"h3=\":443\"; ma=2592000,h3-29=\":443\"; ma=2592000","Transfer-Encoding":"chunked"}},"candidates":[{"content":{"parts":[{"text":"This tool can only search for optical imagery, and does not support radar sensors such as Sentinel-1.\n\nHowever, I can search for Sentinel-2 optical images over the same area and period; would that work for you? I will use a cloud cover maximum of 20% to match your \"low cloud cover\" request.\n"}],"role":"model"},"finish_reason":"STOP","avg_logprobs":-0.2103152620619622}],"model_version":"gemini-2.0-flash","response_id":"igEkafOgIqGe0-kP48_JqAI","usage_metadata":{"candidates_token_count":69,"candidates_tokens_details":[{"modality":"TEXT","token_count":69}],"prompt_token_count":5008,"prompt_tokens_details":[{"modality":"TEXT","token_count":5008}],"total_token_count":5077}}
# -----------------------------------------------------------
#
# 2025-11-24 15:56:13,003 - INFO - runners.py:1346 - Closing runner...
# 2025-11-24 15:56:13,003 - INFO - runners.py:1354 - Runner closed.
# 2025-11-24 15:56:13,005 - INFO - rouge_scorer.py:83 - Using default tokenizer.
# 2025-11-24 15:56:13,006 - INFO - local_eval_set_results_manager.py:62 - Writing eval result to file: /home/kimura/work/google5days/capstone/src/capstone/scripts/eval/.adk/eval_history/eval_boundary_1763967373.0065746.evalset_result.json
# INFO:     127.0.0.1:59256 - "POST /apps/eval/eval_sets/boundary/run_eval HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59256 - "GET /apps/eval/eval_results HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59256 - "GET /apps/eval/eval_results/eval_clarification_1763967203.1461153 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/eval_results/eval_normal_1763964441.5809174 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36192 - "GET /apps/eval/eval_results/eval_clarification_1763967192.8083827 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36202 - "GET /apps/eval/eval_results/eval_clarification_1763967203.1472726 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36210 - "GET /apps/eval/eval_results/eval_clarification_1763967203.1466773 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59256 - "GET /apps/eval/eval_results/eval_clarification_1763967192.8092613 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36222 - "GET /apps/eval/eval_results/eval_boundary_1763967373.0065746 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/eval_results/eval_clarification_1763967192.8078449 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36192 - "GET /apps/eval/eval_results/eval_normal_1763962940.6377974 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36202 - "GET /apps/eval/eval_results/eval_normal_1763964441.5820553 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36210 - "GET /apps/eval/eval_results/eval_clarification_1763967192.8088202 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59256 - "GET /apps/eval/eval_results/eval_normal_1763955081.0432987 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36222 - "GET /apps/eval/eval_results/eval_normal_1763950579.9520552 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/eval_results/eval_normal_1763964441.5801435 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36192 - "GET /apps/eval/eval_results/eval_clarification_1763967285.6569138 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36202 - "GET /apps/eval/eval_results/eval_clarification_1763967285.6564734 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36210 - "GET /apps/eval/eval_results/eval_normal_1763950621.7630553 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59256 - "GET /apps/eval/eval_results/eval_normal_1763949314.0963454 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36222 - "GET /apps/eval/eval_results/eval_normal_1763964441.5825143 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/eval_results/eval_clarification_1763967203.145567 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36192 - "GET /apps/eval/eval_results/eval_normal_1763963433.4206395 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36202 - "GET /apps/eval/eval_results/eval_normal_1763965363.2329445 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36210 - "GET /apps/eval/eval_results/eval_normal_1763963353.397912 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:59256 - "GET /apps/eval/eval_results/eval_normal_1763964441.5815268 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36222 - "GET /apps/eval/eval_results/eval_normal_1763966607.2166655 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/eval_results/eval_normal_1763949347.664515 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/eval_sets/Boundary/evals HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /apps/eval/users/user/sessions/e1be6982-d5b7-4d84-99aa-32f3abbbb0be HTTP/1.1" 200 OK
# INFO:     127.0.0.1:36186 - "GET /debug/trace/session/e1be6982-d5b7-4d84-99aa-32f3abbbb0be HTTP/1.1" 200 OK
